# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\HARI KRISHNA\Downloads\cleaned_all_phones.csv")

# %%
data
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
datac=data.copy()

# %%
datac
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   phone_name         1512 non-null   object
#  1   brand              1512 non-null   object
#  2   os                 1512 non-null   object
#  3   inches             1512 non-null   float64
#  4   resolution         1512 non-null   object
#  5   battery            1512 non-null   int64
#  6   battery_type       1512 non-null   object
#  7   ram(GB)            1512 non-null   int64
#  8   announcement_date  1512 non-null   object
#  9   weight(g)          1512 non-null   int64
#  10  storage(GB)        1512 non-null   int64
#  11  video_720p         1512 non-null   bool
#  12  video_1080p        1512 non-null   bool
#  13  video_4K           1512 non-null   bool
#  14  video_8K           1512 non-null   bool
#  15  video_30fps        1512 non-null   bool
# ...

# %% [markdown]
# # q1): how many unique mobiles are there

# %%
brands=datac["brand"].unique()
len(brands)
# Out:
# 13

# %% [markdown]
# # q2):What is the average ram in all mobiles

# %%
data["ram(GB)"].mean()
# Out:
# 6.6838624338624335

# %% [markdown]
# # q3a):Which phone is having the maximum battery

# %%
datac.loc[datac['battery']==datac['battery'].max(),['phone_name','battery']]
# Out:
#     phone_name  battery
# 573         V6     7250

# %% [markdown]
# # q3b):Which phone is having the minimum battery

# %%
datac.loc[datac['battery']==datac['battery'].min(),['phone_name','battery']]
# Out:
#            phone_name  battery
# 62           iPhone 8     1821
# 536  iPhone SE (2020)     1821

# %% [markdown]
# # q4):What is the maximum battery capacity of huawei

# %%
datac.loc[datac["brand"]=="Huawei",["battery"]].max()
# Out:
# battery    7000
# dtype: int64

# %% [markdown]
# # q5a):Which phone battery has the mimimum RAM

# %%
data.loc[data['ram(GB)']==data['ram(GB)'].min(),['brand','ram(GB)']]
# Out:
#        brand  ram(GB)
# 27    Huawei        1
# 28   Samsung        1
# 69   Samsung        1
# 133   Huawei        1
# 182  Samsung        1
# 230  Samsung        1
# 236   Huawei        1
# 244   Xiaomi        1
# 304  Samsung        1
# 363       LG        1
# 550  Samsung        1

# %% [markdown]
# # q5a):Which phone battery has the mimimum RAM

# %%
data.loc[data['ram(GB)']==data['ram(GB)'].max(),['brand','ram(GB)']]
# Out:
#         brand  ram(GB)
# 1505   Xiaomi       24
# 1506  OnePlus       24
# 1510   Realme       24

# %% [markdown]
# # q6): How many phones has android 7.0 as there operating system

# %%
len(data.loc[data["os"]=="Android 7.0",["phone_name","os"]])
# Out:
# 33

# %% [markdown]
# # q7):what is the oldest phone announced also give date of announcement

# %%
datac.loc[datac['announcement_date']==datac['announcement_date'].min(),['phone_name','announcement_date']]
# Out:
#        phone_name announcement_date
# 2  P8 Lite (2017)        01-01-2017
# 3    Redmi Note 4        01-01-2017

# %% [markdown]
# # q8a):Which brand is having least no of phones produced

# %%
datac["brand"].value_counts()
# Out:
# Xiaomi     264
# Oppo       213
# Samsung    206
# Vivo       168
# Realme     157
# Huawei     137
# Honor      124
# LG          75
# OnePlus     47
# Lenovo      43
# Sony        37
# Apple       22
# Google      19
# Name: brand, dtype: int64

# %% [markdown]
# # q8):Which brand is having highest no of phones produced

# %%
datac["brand"].value_counts()
# Out:
# Xiaomi     264
# Oppo       213
# Samsung    206
# Vivo       168
# Realme     157
# Huawei     137
# Honor      124
# LG          75
# OnePlus     47
# Lenovo      43
# Sony        37
# Apple       22
# Google      19
# Name: brand, dtype: int64

# %% [markdown]
# # q 9)a):How many phones support 4K videos

# %%
datac.loc[datac['video_4K']==True,['phone_name']].count()
# Out:
# phone_name    801
# dtype: int64

# %% [markdown]
# # q 9)b):How many phones support 8K videos

# %%
datac.loc[datac['video_8K']==True,['phone_name']].count()
# Out:
# phone_name    86
# dtype: int64

# %% [markdown]
# # q 9)c):How many phones support 2K or 1080p videos

# %%
datac.loc[datac['video_1080p']==True,['phone_name']].count()
# Out:
# phone_name    1503
# dtype: int64

# %% [markdown]
# # q10a):Give me the phone name and brand name having costliest phones

# %%
datac.loc[datac['price(USD)']==datac['price(USD)'].max(),['phone_name','brand','price(USD)']]
# Out:
#     phone_name   brand  price(USD)
# 777     P40 4G  Huawei      2300.0

# %% [markdown]
# # q10b):Give me the phone name and brand name having cheapest phones

# %%
datac.loc[datac['price(USD)']==datac['price(USD)'].min(),['phone_name','brand','price(USD)']]
# Out:
#     phone_name   brand  price(USD)
# 452        C2s  Realme        40.0

# %% [markdown]
# # q 10): How many phones supports Li-Po and Li-ion Battery

# %%
a=data.loc[data["battery_type"]=="Li-Po",["phone_name"]].count()
b=data.loc[data["battery_type"]=="Li-Ion",["phone_name"]].count()
print("phones that supports Li-po battery\n",a)
print("phones that supports Li-ion battery\n",b)
# Out:
# phones that supports Li-po battery
#  phone_name    1242
# dtype: int64
# phones that supports Li-ion battery
#  phone_name    270
# dtype: int64

# %% [markdown]
# # q 11): How many sony phones supports 720x1280 resolution

# %%
print(len(data.loc[data["resolution"]=="720x1280",["brand","phone_name"]]))
data.loc[data["resolution"]=="720x1280",["brand","phone_name"]]
# Out:
# 41
#        brand          phone_name
# 0     Huawei        Y6II Compact
# 1         LG            K20 plus
# 5       Sony          Xperia XA1
# 9         LG            X power2
# 13      Sony           Xperia L1
# 14      Oppo                 A39
# 16   Samsung     Galaxy Xcover 4
# 17   Samsung         Galaxy J7 V
# 20    Huawei           Y5 (2017)
# 21        LG             Harmony
# 23    Huawei           Y6 (2017)
# 24    Huawei                  Y7
# 30    Xiaomi        Redmi 4 (4X)
# 40   Samsung    Galaxy J5 (2017)
# 41    Huawei            Y7 Prime
# 47    Huawei        P9 lite mini
# 48      Sony  Xperia XZ1 Compact
# 56      Oppo                 A71
# 59    Lenovo                  K8
# 66      Sony    Xperia R1 (Plus)
# 74    Xiaomi  Redmi Y1 (Note 5A)
# 77    Xiaomi       Redmi Y1 Lite
# 79    Xiaomi            Redmi 5A
# 90        LG            Aristo 2
# 91        LG                 X4+
# 93      Sony           Xperia L2
# 96        LG          K10 (2018)
# ...

# %% [markdown]
# # q 12): Print a pivot table for finding the average weights ,total weights,based on brand and battery type

# %%
pd.pivot_table(data,index="brand",columns="battery_type",values=["weight(g)"],aggfunc=["mean"])
# Out:
#                     mean
#                weight(g)
# battery_type      Li-Ion       Li-Po
# brand
# Apple         186.227273         NaN
# Google        190.666667  176.923077
# Honor         165.333333  190.611570
# Huawei        158.354839  187.556604
# LG            154.851852  183.812500
# Lenovo        190.142857  218.586207
# OnePlus              NaN  191.553191
# Oppo          157.833333  183.174603
# Realme        166.833333  189.688742
# Samsung       178.531250  196.727273
# Sony          177.333333  178.769231
# Vivo                 NaN  190.232143
# Xiaomi        179.294118  195.906883
