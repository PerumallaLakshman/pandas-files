# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # DATA ANALYSIS ON CARS

# %%
data=pd.read_csv(r"C:\Users\HARI KRISHNA\Desktop\Clean_Data_pakwheels.csv")

# %%
datac=data.copy()#copy the data for saving original data

# %%
datac
# Out:
#        Unnamed: 0 Company Name Model Name    Price  Model Year   Location  \
# 0               0       Toyota       Vitz  2385000        2017  Islamabad
# 1               1       Toyota    Corolla   111000        2019        KPK
# 2               2       Suzuki       Alto  1530000        2019        KPK
# 3               3       Suzuki       Alto  1650000        2019     Punjab
# 4               4       Toyota    Corolla  1435000        2010  Islamabad
# ...           ...          ...        ...      ...         ...        ...
# 46017       46018        Honda      Vezel  3400000        2015     Punjab
# 46018       46019       Toyota       Aqua  2450000        2015     Punjab
# 46019       46020        Honda      Civic  3250000        2015     Punjab
# 46020       46021       Toyota       Aqua  3000000        2016     Punjab
# 46021       46022       Toyota    Corolla  2250000        2015     Punjab
#
#        Mileage Engine Type  Engine Capacity     Color  Assembly   Body Type  \
# ...

# %%
datac.drop(["Unnamed: 0"],inplace=True,axis=1)# here we drop the un useful column[Unnamed: 0]

# %%
datac
# Out:
#       Company Name Model Name    Price  Model Year   Location  Mileage  \
# 0           Toyota       Vitz  2385000        2017  Islamabad     9869
# 1           Toyota    Corolla   111000        2019        KPK    11111
# 2           Suzuki       Alto  1530000        2019        KPK    17500
# 3           Suzuki       Alto  1650000        2019     Punjab     9600
# 4           Toyota    Corolla  1435000        2010  Islamabad   120000
# ...            ...        ...      ...         ...        ...      ...
# 46017        Honda      Vezel  3400000        2015     Punjab    32000
# 46018       Toyota       Aqua  2450000        2015     Punjab    52000
# 46019        Honda      Civic  3250000        2015     Punjab   125000
# 46020       Toyota       Aqua  3000000        2016     Punjab    60000
# 46021       Toyota    Corolla  2250000        2015     Punjab    77000
#
#       Engine Type  Engine Capacity     Color  Assembly   Body Type  \
# ...

# %%
data.isna()#checking weather null values are not
# Out:
#        Unnamed: 0  Company Name  Model Name  Price  Model Year  Location  \
# 0           False         False       False  False       False     False
# 1           False         False       False  False       False     False
# 2           False         False       False  False       False     False
# 3           False         False       False  False       False     False
# 4           False         False       False  False       False     False
# ...           ...           ...         ...    ...         ...       ...
# 46017       False         False       False  False       False     False
# 46018       False         False       False  False       False     False
# 46019       False         False       False  False       False     False
# 46020       False         False       False  False       False     False
# 46021       False         False       False  False       False     False
#
#        Mileage  Engine Type  Engine Capacity  Color  Assembly  Body Type  \
# ...

# %%
datac.duplicated()# to verify ewather duplicated rows are not
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 46017    False
# 46018    False
# 46019    False
# 46020    False
# 46021    False
# Length: 46022, dtype: bool

# %%
# finally we dont have null values and duplicated rows so the data is clear

# %%
# In the column "Company Name" represents the name of the company of the cars and it is an object type
# In the column "Model Name" represents the name of the model of the cars and it is an object type
# In the column "price" represents the cost  of the cars and it is an int type
# In the column "Model year" represents the year of the model of the cars and it is an int type
# In the column "Location" represents the location of the company of the cars and it is an object type
# In the column "Mileage" represents the mileage of the particular model of the car and it is an int type
# In the column "Engine Type" represents the name of the engine of the cars and it is an object type
# In the column "Engine Capacity" represents the  capacity of the model of the cars engine and it is an int type
# In the column "Color" represents the Color  of the cars and it is an object type
# In the column "Assembly" represents the type of the model of the cars and it is an object type
# In the column "Body Type" represents the type and outlet  of the cars and it is an object type
# In the column "Transmission Type" represents the gear system for the particular model of the car and it is an object type
# In the column "Registration Status" represents theweather the particular model of the car is regestered or not and it is an object type

# %%
datac.columns
# Out:
# Index(['Company Name', 'Model Name', 'Price', 'Model Year', 'Location',
#        'Mileage', 'Engine Type', 'Engine Capacity', 'Color', 'Assembly',
#        'Body Type', 'Transmission Type', 'Registration Status'],
#       dtype='object')

# %% [markdown]
# # so here is a data frame so we do the analysis based on pandas for better and effective analysis

# %%
# Here we have a lot of columns are based on categorical data and few columns are based on numerical data

# %%
datac.agg({"Price":["min","max","mean"]})# we can obtain the data for single and multiple columns and internal required functions as we want
# Out:
#              Price
# min   1.110000e+05
# max   7.750000e+07
# mean  2.014153e+06

# %%
datac.agg({"Model Year":[min,max]})
# Out:
#      Model Year
# min        1990
# max        2019

# %%
datac.agg({"Mileage":[min,max]})
# Out:
#      Mileage
# min        1
# max   999999

# %%
datac["Company Name"].unique()
# Out:
# array(['Toyota', 'Suzuki', 'Honda', 'Mitsubishi', 'Nissan', 'Daihatsu',
#        'Audi', 'Chevrolet', 'Mercedes', 'Hyundai', 'Daewoo', 'BMW', 'FAW',
#        'Range', 'DFSK', 'KIA', 'Lexus', 'United', 'SsangYong', 'Mazda',
#        'Subaru', 'Porsche', 'Chery', 'Fiat', 'Land', 'MINI', 'Hummer',
#        'Jeep', 'Jaguar', 'Adam', 'Volvo'], dtype=object)

# %%
datac["Model Name"].value_counts()
# Out:
# Corolla     8198
# Mehran      4766
# Civic       4214
# Cultus      3645
# City        3109
#             ...
# Terrano        1
# Macan          1
# Panamera       1
# FX             1
# CJ             1
# Name: Model Name, Length: 196, dtype: int64

# %%
datac["Model Year"].value_counts()
# Out:
# 2017    3892
# 2015    3842
# 2016    3776
# 2014    3438
# 2018    3312
# 2019    2739
# 2007    2645
# 2013    2584
# 2012    2445
# 2011    2168
# 2006    2099
# 2010    1781
# 2005    1746
# 2008    1687
# 2004    1243
# 2009    1171
# 2003     903
# 2002     567
# 2001     518
# 2000     458
# 1996     442
# 1997     404
# 1998     403
# 1999     384
# 1995     339
# 1994     248
# 1993     242
# 1992     213
# 1990     178
# 1991     155
# Name: Model Year, dtype: int64

# %%
datac["Location"].value_counts()
# Out:
# Punjab         24732
# Sindh           8758
# Islamabad       6659
# KPK             5301
# Balochistan      324
# Kashmir          248
# Name: Location, dtype: int64

# %%
datac["Engine Type"].unique()
# Out:
# array(['Petrol', 'Diesel', 'Hybrid'], dtype=object)

# %%
datac["Engine Type"].value_counts()
# Out:
# Petrol    43590
# Hybrid     1439
# Diesel      993
# Name: Engine Type, dtype: int64

# %%
datac.agg(func=["min","max","mean","std","count"])
# Out:
# C:\Users\HARI KRISHNA\AppData\Local\Temp\ipykernel_12824\170256889.py:1: FutureWarning: ['Company Name', 'Model Name', 'Location', 'Engine Type', 'Color', 'Assembly', 'Body Type', 'Transmission Type', 'Registration Status'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   datac.agg(func=["min","max","mean","std","count"])
#       Company Name Model Name         Price    Model Year     Location  \
# min           Adam          3  1.110000e+05   1990.000000  Balochistan
# max          Volvo         iQ  7.750000e+07   2019.000000        Sindh
# mean           NaN        NaN  2.014153e+06   2011.035374          NaN
# std            NaN        NaN  2.939071e+06      6.399403          NaN
# count        46022      46022  4.602200e+04  46022.000000        46022
#
#              Mileage Engine Type  Engine Capacity     Color  Assembly  \
# ...

# %%
datac[["Price","Mileage","Engine Capacity"]].agg(func=["min","max","mean","std","count"])
# Out:
#               Price        Mileage  Engine Capacity
# min    1.110000e+05       1.000000        16.000000
# max    7.750000e+07  999999.000000      6600.000000
# mean   2.014153e+06   90965.128243      1313.115575
# std    2.939071e+06   63656.656034       614.690832
# count  4.602200e+04   46022.000000     46022.000000

# %%
datab=datac.groupby("Company Name")

# %%
datab.ngroups
# Out:
# 31

# %%
datab["Price","Mileage","Engine Capacity"].agg(func=["min","max","mean","std","count"])
# Out:
# C:\Users\HARI KRISHNA\AppData\Local\Temp\ipykernel_12824\3818231299.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   datab["Price","Mileage","Engine Capacity"].agg(func=["min","max","mean","std","count"])
#                  Price                                              Mileage  \
#                    min       max          mean           std  count     min
# Company Name
# Adam            210000    210000  2.100000e+05           NaN      1  100000
# Audi           1000000  17500000  8.582803e+06  3.102661e+06    208      24
# BMW            1150000  37500000  5.858343e+06  6.859078e+06    137     450
# Chery           435000    620000  5.337500e+05  6.384971e+04      8   59000
# Chevrolet       300000   1150000  6.716250e+05  2.587207e+05     40   60000
# DFSK            750000   4500000  2.029444e+06  1.367999e+06      9     100
# ...

# %% [markdown]
# # hence by using the agg() function with group by specification we can got the basic statistitical data of mean,minimum,maximum,standard deviation ,count

# %%
datab=datac.groupby("Engine Type")
datab["Price","Mileage","Engine Capacity"].agg(func=["min","max","mean","std","count"])
# Out:
# C:\Users\HARI KRISHNA\AppData\Local\Temp\ipykernel_12824\2009789436.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   datab["Price","Mileage","Engine Capacity"].agg(func=["min","max","mean","std","count"])
#               Price                                              Mileage  \
#                 min       max          mean           std  count     min
# Engine Type
# Diesel       290000  15500000  2.549018e+06  2.228165e+06    993    4000
# Hybrid       250000  51500000  3.484074e+06  2.017865e+06   1439    2000
# Petrol       111000  77500000  1.953444e+06  2.965004e+06  43590       1
#
#                                                         Engine Capacity        \
#                 max           mean           std  count             min   max
# Engine Type
# Diesel       470000  156224.297080  75989.557142    993             800  4700
# ...

# %%
datab=datac.groupby("Color")
datab["Price","Mileage","Engine Capacity"].agg(func=["min","max","mean","std","count"])
# Out:
# C:\Users\HARI KRISHNA\AppData\Local\Temp\ipykernel_12824\3061566507.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   datab["Price","Mileage","Engine Capacity"].agg(func=["min","max","mean","std","count"])
#              Price                                              Mileage  \
#                min       max          mean           std  count     min
# Color
# Assembly    200000  42500000  2.245749e+06  3.864755e+06   1382     450
# Beige       230000  23500000  1.443181e+06  1.412758e+06    580    4192
# Black       185000  65000000  2.978100e+06  4.284365e+06   6026      12
# Blue        160000  51500000  1.356260e+06  1.676894e+06   2127       1
# Bronze      410000  12900000  2.168867e+06  1.424042e+06    211    5200
# Brown       290000  35000000  2.238717e+06  2.411685e+06    269      18
# Burgundy    304000  34000000  2.181375e+06  2.554930e+06    307    1200
# ...

# %%
datab=datac.groupby("Model Name")
datab["Price","Mileage","Engine Capacity"].agg(func=["min","max","mean","std","count"])
# Out:
# C:\Users\HARI KRISHNA\AppData\Local\Temp\ipykernel_12824\1457163229.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   datab["Price","Mileage","Engine Capacity"].agg(func=["min","max","mean","std","count"])
#                Price                                             Mileage  \
#                  min       max          mean           std count     min
# Model Name
# 3            1150000   8900000  3.338250e+06  2.043126e+06    44   18000
# 5            1700000  20000000  4.551618e+06  4.959293e+06    34   22000
# 7            2500000  37500000  9.355147e+06  1.146907e+07    34     450
# A3           4495000   7000000  5.861667e+06  7.410273e+05    36    4000
# A4           1000000  10600000  6.761074e+06  2.116176e+06    68    2300
# ...              ...       ...           ...           ...   ...     ...
# X5           1850000  14500000  6.228571e+06  5.408470e+06     7   58000
# ...

# %%
datab=datac.groupby(["Body Type","Transmission Type"])
datab["Price","Mileage","Engine Capacity"].agg(func=["min","max","mean","std","count"])
# Out:
# C:\Users\HARI KRISHNA\AppData\Local\Temp\ipykernel_12824\2756465270.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   datab["Price","Mileage","Engine Capacity"].agg(func=["min","max","mean","std","count"])
#                                 Price                                        \
#                                   min       max          mean           std
# Body Type  Transmission Type
# Cross Over Automatic          1625000  25000000  4.212113e+06  1.213473e+06
#            Manual              835000   8000000  4.111250e+06  3.058100e+06
# Hatchback  Automatic           120000  24500000  1.741722e+06  6.468184e+05
#            Manual              130000   5500000  8.362729e+05  3.972468e+05
# Mini Van   Automatic           650000   7500000  1.694300e+06  9.702151e+05
#            Manual              250000   2200000  7.603354e+05  3.085627e+05
# ...

# %%
datab=datac.groupby(["Body Type","Registration Status"])
datab["Price","Mileage","Engine Capacity"].agg(func=["min","max","mean","std","count"])
# Out:
# C:\Users\HARI KRISHNA\AppData\Local\Temp\ipykernel_12824\3557623507.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   datab["Price","Mileage","Engine Capacity"].agg(func=["min","max","mean","std","count"])
#                                   Price                                        \
#                                     min       max          mean           std
# Body Type  Registration Status
# Cross Over Registered            835000  25000000  4.107628e+06  1.442869e+06
#            Un-Registered        2950000   9300000  4.370921e+06  7.824683e+05
# Hatchback  Registered            120000  24500000  1.068644e+06  5.876984e+05
#            Un-Registered         360000   5500000  2.144071e+06  6.107495e+05
# Mini Van   Registered            250000   7500000  1.007215e+06  6.622645e+05
#            Un-Registered         995000   4500000  2.180183e+06  9.880289e+05
# ...

# %% [markdown]
# # we also can give multiple specifications based on requirement for group by

# %%
datab=datac.groupby(["Registration Status"])
datab["Price","Mileage","Engine Capacity"].agg(func=["min","max","mean","std","count"])
# Out:
# C:\Users\HARI KRISHNA\AppData\Local\Temp\ipykernel_12824\675137838.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   datab["Price","Mileage","Engine Capacity"].agg(func=["min","max","mean","std","count"])
#                       Price                                               \
#                         min       max          mean           std  count
# Registration Status
# Registered           111000  65000000  1.845659e+06  2.357512e+06  42693
# Un-Registered        360000  77500000  4.175020e+06  6.566579e+06   3329
#
#                     Mileage                                             \
#                         min     max          mean           std  count
# Registration Status
# Registered                1  999999  94784.497295  63873.511656  42693
# Un-Registered             1  370000  41983.355062  33339.868406   3329
#
#                     Engine Capacity
# ...

# %% [markdown]
# #  here is the data is divided into two types which are reserved and un reserved

# %%
datac.loc[datac["Registration Status"]=="Registered",["Company Name","Model Name","Price","Model Year","Location","Mileage","Engine Type","Engine Capacity","Color","Assembly","Body Type","Transmission Type"]]
# Out:
#       Company Name Model Name    Price  Model Year   Location  Mileage  \
# 1           Toyota    Corolla   111000        2019        KPK    11111
# 3           Suzuki       Alto  1650000        2019     Punjab     9600
# 4           Toyota    Corolla  1435000        2010  Islamabad   120000
# 5            Honda      Civic  3850000        2017     Punjab    22000
# 6           Suzuki      Wagon  1440000        2017     Punjab    31000
# ...            ...        ...      ...         ...        ...      ...
# 46015       Suzuki     Cultus  1825000        2018     Punjab    16000
# 46016        Honda      Civic  3300000        2017     Punjab    40000
# 46019        Honda      Civic  3250000        2015     Punjab   125000
# 46020       Toyota       Aqua  3000000        2016     Punjab    60000
# 46021       Toyota    Corolla  2250000        2015     Punjab    77000
#
#       Engine Type  Engine Capacity     Color  Assembly  Body Type  \
# ...

# %%
datac.loc[datac["Registration Status"]=="Un-Registered",["Company Name","Model Name","Price","Model Year","Location","Mileage","Engine Type","Engine Capacity","Color","Assembly","Body Type","Transmission Type"]]
 here is the data is divided into two types which are reserved and un reserved
# Out:
#       Company Name Model Name    Price  Model Year   Location  Mileage  \
# 0           Toyota       Vitz  2385000        2017  Islamabad     9869
# 2           Suzuki       Alto  1530000        2019        KPK    17500
# 18          Suzuki      Wagon  1625000        2016     Punjab    45000
# 57          Toyota      Passo  2350000        2017     Punjab    35000
# 67          Toyota      Prius  5200000        2016     Punjab    15205
# ...            ...        ...      ...         ...        ...      ...
# 46000       Toyota       Aqua  2600000        2015        KPK    60000
# 46006     Daihatsu       Mira  1800000        2016      Sindh    23000
# 46012       Nissan       Moco  1565000        2015     Punjab    63000
# 46017        Honda      Vezel  3400000        2015     Punjab    32000
# 46018       Toyota       Aqua  2450000        2015     Punjab    52000
#
#       Engine Type  Engine Capacity     Color  Assembly   Body Type  \
# ...

# %%
# hence the data can be still manpulated and analysed into many different way on requirement
